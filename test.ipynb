# %%
//ハローワールド出力
console.log('Hello World');
# Out:
# Hello World

# %%
// fizzのみ
for (let i = 1; i <= 15; i++){
    if (i % 3 == 0) {
        console.log('Fizz');
    }
    else {
        console.log(i);
    }
  }
# Out:
# 1
# 2
# Fizz
# 4
# 5
# Fizz
# 7
# 8
# Fizz
# 10
# 11
# Fizz
# 13
# 14
# Fizz

# %%
// fizzbuzz
for (let i = 1; i <= 15; i++){
    if (i % 3 == 0 && i % 5 == 0) {
        console.log('Fizzbuzz');
    } 
    else if (i % 3 == 0) {
        console.log('Fizz');
    } 
    else if (i % 5 == 0) {
        console.log('Buzz');
    } 
    else {
        console.log(i);
    }
}
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# Fizzbuzz

# %%
// forの多重ループ
for (let i = 1 ; i <= 9 ; i++) {
    for (let j = 1 ; j <= 9 ; j++) {
        console.log(i * j);
    }
}
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 8
# 16
# 24
# 32
# 40
# 48
# 56
# 64
# 72
# 9
# 18
# 27
# 36
# 45
# 54
# 63
# 72
# 81
